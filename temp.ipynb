# %%
source genaiops/bin/activate

# %%
import sys

sys.argv[1]
# Out:
# '--f=/Users/tranphuong/Library/Jupyter/runtime/kernel-v348dafe47c7722fd1510d9657601b6c8960945eb4.json'

# %%
len(sys.argv)
# Out:
# 2
